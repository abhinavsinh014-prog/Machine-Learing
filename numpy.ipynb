# %%
import numpy as np  
my_array = np.array([1, 2, 3, 4, 5])
print(my_array)
# Out:
# [1 2 3 4 5]

# %%
print(type(my_array))
# Out:
# <class 'numpy.ndarray'>

# %%
np.random.random((3, 2))
# Out:
# array([[0.25854849, 0.52032972],
#        [0.047961  , 0.84857852],
#        [0.20503296, 0.99939702]])
