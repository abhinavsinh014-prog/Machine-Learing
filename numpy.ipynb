# %%
import numpy as np  
my_array = np.array([1, 2, 3, 4, 5])
print(my_array)
# Out:
# [1 2 3 4 5]

# %%
print(type(my_array))
# Out:
# <class 'numpy.ndarray'>

# %%
np.random.random((3, 2))
# Out:
# array([[0.25854849, 0.52032972],
#        [0.047961  , 0.84857852],
#        [0.20503296, 0.99939702]])

# %%
import numpy as np  
my_array = np.array([1, 2, 3, 4, 5])
numbr = 18

new_array = my_array + numbr
print(new_array)
# Out:
# [19 20 21 22 23]

# %%
import numpy as np  
my_array = np.array([1, 2, 3, 4, 5])
your_array = np.array([6, 7, 8, 9, 10])
result_array = my_array + your_array
print(result_array)
# Out:
# [ 7  9 11 13 15]
