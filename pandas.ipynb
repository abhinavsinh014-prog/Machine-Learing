# %%
import pandas as pd
import numpy as np

# %%
df = pd.DataFrame({
    'a': [1, 2, 3,np.nan, 5],
    'b': [5, 6, np.nan, 8, 9],
    'c': [10, 11, 12, 13, 14],
    'd': [15, None, None, None, 19]
})

# %%
print(df.isna().sum())
# Out:
# a    1
# b    1
# c    0
# d    3
# dtype: int64
