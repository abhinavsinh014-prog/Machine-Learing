# %%
import pandas as pd
import numpy as np

# %%
df = pd.DataFrame({
    'a': [1, 2, 3,np.nan, 5],
    'b': [5, 6, np.nan, 8, 9],
    'c': [10, 11, 12, None, 14],
    'd': [15, 16, None, None, 19]
})
